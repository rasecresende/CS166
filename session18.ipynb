# %% [markdown]
# # Exercise 15.2

# %% [markdown]
# In a complete graph: n*(n-1)/2
#
# Regular graph = k*n/2

# %% [markdown]
# # Exercise 15.3

# %%
import numpy as np
import networkx as nx

# %%
n = 4
edges = [(i, j) for i in range(n) for j in range(0, i)]

g = nx.Graph(edges)
nx.draw(g)

# %%
n = 5
edges = [(i, j) for i in range(n) for j in range(0, i)]

g = nx.Graph(edges)
nx.draw(g)

# %%
n = 5
edges = [(i, j) for i in range(0, 2) for j in range(2, 5)]
g = nx.Graph(edges)
pos = nx.drawing.layout.bipartite_layout(g, [0, 1])
nx.draw(g, pos = pos)

# %%
n = 6
edges = [(i, j) for i in range(0, 3) for j in range(3, 6)]
g = nx.Graph(edges)
pos = nx.drawing.layout.bipartite_layout(g, [0, 1, 2])
nx.draw(g, pos = pos)

# %% [markdown]
# # Exercise 15.4

# %% [markdown]
# A connected tree graph is a graph in which there is no cycle but there will always be a path between two nodes. Since they can't go back to the starting node, we always have n-1 edges.

# %% [markdown]
# # Exercise 15.10

# %%
g = nx.hypercube_graph(4)
nx.draw(g)

# %%
g = nx.ladder_graph(5)
nx.draw(g)

# %%
g = nx.barbell_graph(20, 1)
nx.draw(g)

# %%
g = nx.wheel_graph(100)
nx.draw(g)
